# %% [markdown]
# # dHybridR M06_th60 Analysis
# #### Here we analyze a specific simulation, assuming that FPC data has already been generated
#
# Note: we generate most plots twice, once to make appear in notebook, once to save as png. TODO: streamline this

# %%
#Need this to add libraries in parent folder
import sys
sys.path.append('..')
sys.path.append('.')
sys.path.append('../lib')

# %%
import lib.analysis as anl 
import lib.array_ops as ao
import lib.data_h5 as dh5
import lib.data_netcdf4 as dnc
import lib.fpc as fpc
import lib.frametransform as ft
import lib.metadata as md

import lib.plot.oned as plt1d
import lib.plot.twod as plt2d
import lib.plot.debug as pltdebug
import lib.plot.fourier as pltfr
import lib.plot.resultsmanager as rsltmng
import lib.plot.velspace as pltvv

import os
import math
import numpy as np

# %% [markdown]
# ## Load data

# %%
# load analysis file
analysisflnm = '../analysisinputsperp/m06_th60input.txt'
path,resultsdir,vmax,dv,numframe,dx,xlim,ylim,zlim = anl.analysis_input(flnm = analysisflnm)
path_particles = path+'Output/Raw/Sp01/raw_sp01_{:08d}.h5'

# %%
#make results directory
resultstag = 'M06_th60'
resultsdir = resultstag+'results/'
os.system('mkdir ' + resultsdir)
# Out:
# 256

# %%
#load fields
dfields = dh5.field_loader(path=path,num=numframe)

#load flow data
dflow = dh5.flow_loader(path=path,num=numframe)

# %%
#check that xlim ylim and zlim are not none
#if so, use boundaries of box
cellsizexx = dfields['ex_xx'][1]-dfields['ex_xx'][0]
cellsizeyy = dfields['ex_yy'][1]-dfields['ex_yy'][0]
cellsizezz = dfields['ex_zz'][1]-dfields['ex_zz'][0]

if(xlim is None):
    xlim = [dfields['ex_xx'][0]-cellsizexx/2.,dfields['ex_xx'][-1]+cellsizexx/2.]
if(ylim is None):
    ylim = [dfields['ex_yy'][0]-cellsizeyy/2.,dfields['ex_yy'][-1]+cellsizeyy/2.]
if(zlim is None):
    zlim = [dfields['ex_zz'][0]-cellsizeyy/2.,dfields['ex_zz'][-1]+cellsizeyy/2.]

# %%
# load particle data
dparticles = dh5.read_box_of_particles(path_particles, numframe, xlim[0], xlim[1], ylim[0], ylim[1], zlim[0], zlim[1])

# %%
all_dfields = dh5.all_dfield_loader(path=path, verbose=False)

# %% [markdown]
# ### Lorentz transform fields and shift frame of flow

# %%
vshock, xshockvals = ft.shock_from_ex_cross(all_dfields)
# Out:
# Warning, using dt = 0.01 Omega^-1... TODO: automate loading this...

# %%
## (Optional) Check if shock was tracked well. We use the back half in time to fit to a line
#plt1d.time_stack_line_plot(all_dfields,'ex',pts = xshockvals)

# %%
#loretnz transform fields
dfields = ft.lorentz_transform_vx(dfields,vshock)
_fields = []
for k in range(0,len(all_dfields['dfields'])):
    _fields.append(ft.lorentz_transform_vx(all_dfields['dfields'][k],vshock))
all_dfields['dfields'] = _fields

#tranform flow
dflow = ft.transform_flow(dflow,vshock)

# %%
# (Optional) plot all the lorentz transformed fields
plt1d.plot_all_fields(dfields, axis='_xx', xxindex = 0, yyindex = 0, zzindex = 0, flnm=resultsdir+resultstag+'fields.png')
plt1d.plot_all_fields(dfields, axis='_xx', xxindex = 0, yyindex = 0, zzindex = 0)

# %%
# (Optional) plot flow in the etimated frame of the shock
plt1d.plot_all_flow(dflow, axis='_xx', xxindex = 0, yyindex = 0, zzindex = 0, flnm=resultsdir+resultstag+'flow.png')
plt1d.plot_all_flow(dflow, axis='_xx', xxindex = 0, yyindex = 0, zzindex = 0)

# %% [markdown]
# ### Load FPC data

# %%
ncflnm = '../M06_th60results/m06_th60.nc'
Hist, CEx, CEy, CEz, vx, vy, vz, x, enerCEx, enerCEy, enerCEz, Vframe_relative_to_sim, metadata_in, params_in = dnc.load3Vnetcdf4(ncflnm)

# %% [markdown]
# ### Look for signature bounds

# %%
startval = 23.0#lower bound for sda metadata = 1 (di)
endval = 28.5#upper bound for sda metadata = 1 (di)

# %%
#option one, use Ex(x,y=0,z=0) to find SDA bounds. Should range from the start of the ramp to the first zero crossing
yyindex = 0
zzindex = 0
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = startval, axvx2 = endval,flnm=resultsdir+resultstag+'shockbounds.png')
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = startval, axvx2 = endval)

# %%
#option two (better but harder), look at the FPC signatures and see when the shock starts and stops

#Plot FPCs and dist funcs at start val-------------------------------------------------------------
#grab index of starval
i = ao.find_nearest(x, startval)

#Project onto 2d axis
H_xy = ao.array_3d_to_2d(Hist[i],'xy')
H_xz = ao.array_3d_to_2d(Hist[i],'xz')
H_yz = ao.array_3d_to_2d(Hist[i],'yz')
CEx_xy = ao.array_3d_to_2d(CEx[i],'xy')
CEx_xz = ao.array_3d_to_2d(CEx[i],'xz')
CEx_yz = ao.array_3d_to_2d(CEx[i],'yz')
CEy_xy = ao.array_3d_to_2d(CEy[i],'xy')
CEy_xz = ao.array_3d_to_2d(CEy[i],'xz')
CEy_yz = ao.array_3d_to_2d(CEy[i],'yz')
CEz_xy = ao.array_3d_to_2d(CEz[i],'xy')
CEz_xz = ao.array_3d_to_2d(CEz[i],'xz')
CEz_yz = ao.array_3d_to_2d(CEz[i],'yz')

#plot
pltvv.plot_cor_and_dist_supergrid(vx, vy, vz, vmax,
                                H_xy, H_xz, H_yz,
                                CEx_xy,CEx_xz, CEx_yz,
                                CEy_xy,CEy_xz, CEy_yz,
                                CEz_xy,CEz_xz, CEz_yz,flnm=resultsdir+resultstag+'superplotstartval.png')
pltvv.plot_cor_and_dist_supergrid(vx, vy, vz, vmax,
                                H_xy, H_xz, H_yz,
                                CEx_xy,CEx_xz, CEx_yz,
                                CEy_xy,CEy_xz, CEy_yz,
                                CEz_xy,CEz_xz, CEz_yz)

# %%
#plot where above signature is
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = startval,flnm=resultsdir+resultstag+'startvalpos.png')
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = startval)

# %%
#Plot FPCs and dist funcs at end val--------------------------------------------------------------
#grab index of starval
i = ao.find_nearest(x, endval)

#Project onto 2d axis
H_xy = ao.array_3d_to_2d(Hist[i],'xy')
H_xz = ao.array_3d_to_2d(Hist[i],'xz')
H_yz = ao.array_3d_to_2d(Hist[i],'yz')
CEx_xy = ao.array_3d_to_2d(CEx[i],'xy')
CEx_xz = ao.array_3d_to_2d(CEx[i],'xz')
CEx_yz = ao.array_3d_to_2d(CEx[i],'yz')
CEy_xy = ao.array_3d_to_2d(CEy[i],'xy')
CEy_xz = ao.array_3d_to_2d(CEy[i],'xz')
CEy_yz = ao.array_3d_to_2d(CEy[i],'yz')
CEz_xy = ao.array_3d_to_2d(CEz[i],'xy')
CEz_xz = ao.array_3d_to_2d(CEz[i],'xz')
CEz_yz = ao.array_3d_to_2d(CEz[i],'yz')

#plot
pltvv.plot_cor_and_dist_supergrid(vx, vy, vz, vmax,
                                H_xy, H_xz, H_yz,
                                CEx_xy,CEx_xz, CEx_yz,
                                CEy_xy,CEy_xz, CEy_yz,
                                CEz_xy,CEz_xz, CEz_yz,flnm=resultsdir+resultstag+'superplotendval.png')
pltvv.plot_cor_and_dist_supergrid(vx, vy, vz, vmax,
                                H_xy, H_xz, H_yz,
                                CEx_xy,CEx_xz, CEx_yz,
                                CEy_xy,CEy_xz, CEy_yz,
                                CEz_xy,CEz_xz, CEz_yz)

# %%
#plot where above signature is
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = endval,flnm=resultsdir+resultstag+'endvalpos.png')
plt1d.plot_field(dfields, 'ex', axis='_xx', yyindex = yyindex, zzindex = zzindex, axvx1 = endval)

# %%
#set metadata using add Metadata script
cmd = 'python3 ../scripts/addMetadata.py ' + analysisflnm + ' ' + ncflnm + ' ' + str(startval) + ' ' + str(endval)
os.system(cmd)
# Out:
# 0

# %% [markdown]
# ### Look for shock rippling

# %% [markdown]
# #### Make pmesh of fields

# %%
#plot xy plane at z=0 
plt2d.make_field_pmesh(dfields,'bz','xy',takeaxisaverage=False, xxindex=float('nan'), yyindex=float('nan'), zzindex=0, xlimmin=None,xlimmax=None,flnm=resultsdir+resultstag+'Bzpmesh.png')
plt2d.make_field_pmesh(dfields,'bz','xy',takeaxisaverage=False, xxindex=float('nan'), yyindex=float('nan'), zzindex=0, xlimmin=None,xlimmax=None)

# %%
#zoom in on potential ripple xy plane at z=0
plt2d.make_field_pmesh(dfields,'bz','xy',takeaxisaverage=False, xxindex=float('nan'), yyindex=float('nan'), zzindex=0, xlimmin=startval,xlimmax=endval,flnm=resultsdir+resultstag+'Bzpeshzoomed.png')
plt2d.make_field_pmesh(dfields,'bz','xy',flnm = '',takeaxisaverage=False, xxindex=float('nan'), yyindex=float('nan'), zzindex=0, xlimmin=startval,xlimmax=endval)

# %% [markdown]
# #### Make stacked line plot

# %%
plt1d.plot_stack_field_along_x(dfields,'bz','_yy',yyindex=0,zzindex=0,xlow=startval,xhigh=endval,flnm=resultsdir+resultstag+'stackedripple.png')
plt1d.plot_stack_field_along_x(dfields,'bz','_yy',yyindex=0,zzindex=0,xlow=startval,xhigh=endval)

# %% [markdown]
# ### Diagnose corrugation instability
# #### look at number of significant wave modes in fourier space
# #### still WIP

# %%
shockval = 15.0 #di, some slice in the ramp of the shock
i = ao.find_nearest(x, shockval)
pltfr.plot_fft_norm(dfields,'bz','yz',takeaxisaverage=False, xxindex=i, yyindex=float('nan'), zzindex=float('nan'), plotlog = False, xaxislim=None, yaxislim=None,flnm=resultsdir+resultstag+'2dfftinramp.png')
pltfr.plot_fft_norm(dfields,'bz','yz',flnm = '',takeaxisaverage=False, xxindex=i, yyindex=float('nan'), zzindex=float('nan'), plotlog = False, xaxislim=None, yaxislim=None)

# %% [markdown]
# ### Generate sweep gifs

# %% [markdown]
# #### Generate sweeps of superplot

# %%
pltvv.make_superplot_gif(vx,vy,vz,vmax,Hist,CEx,CEy,CEz,x,resultsdir+'superplotscanfiles',resultsdir+resultstag+'superplot.gif')
# Out:
# Making plot 0 of 192
# Making plot 1 of 192
# Making plot 2 of 192
# Making plot 3 of 192
# Making plot 4 of 192
# Making plot 5 of 192
# Making plot 6 of 192
# Making plot 7 of 192
# Making plot 8 of 192
# Making plot 9 of 192
# Making plot 10 of 192
# Making plot 11 of 192
# Making plot 12 of 192
# Making plot 13 of 192
# Making plot 14 of 192
# Making plot 15 of 192
# Making plot 16 of 192
# Making plot 17 of 192
# Making plot 18 of 192
# Making plot 19 of 192
# Making plot 20 of 192
# Making plot 21 of 192
# Making plot 22 of 192
# Making plot 23 of 192
# Making plot 24 of 192
# Making plot 25 of 192
# Making plot 26 of 192
# Making plot 27 of 192
# Making plot 28 of 192
# Making plot 29 of 192
# Making plot 30 of 192
# Making plot 31 of 192
# Making plot 32 of 192
# Making plot 33 of 192
# Making plot 34 of 192
# Making plot 35 of 192
# Making plot 36 of 192
# Making plot 37 of 192
# Making plot 38 of 192
# Making plot 39 of 192
# Making plot 40 of 192
# Making plot 41 of 192
# Making plot 42 of 192
# Making plot 43 of 192
# Making plot 44 of 192
# Making plot 45 of 192
# Making plot 46 of 192
# Making plot 47 of 192
# Making plot 48 of 192
# Making plot 49 of 192
# Making plot 50 of 192
# Making plot 51 of 192
# Making plot 52 of 192
# Making plot 53 of 192
# Making plot 54 of 192
# Making plot 55 of 192
# Making plot 56 of 192
# Making plot 57 of 192
# Making plot 58 of 192
# Making plot 59 of 192
# Making plot 60 of 192
# Making plot 61 of 192
# Making plot 62 of 192
# Making plot 63 of 192
# Making plot 64 of 192
# Making plot 65 of 192
# Making plot 66 of 192
# Making plot 67 of 192
# Making plot 68 of 192
# Making plot 69 of 192
# Making plot 70 of 192
# Making plot 71 of 192
# Making plot 72 of 192
# Making plot 73 of 192
# Making plot 74 of 192
# Making plot 75 of 192
# Making plot 76 of 192
# Making plot 77 of 192
# Making plot 78 of 192
# Making plot 79 of 192
# Making plot 80 of 192
# Making plot 81 of 192
# Making plot 82 of 192
# Making plot 83 of 192
# Making plot 84 of 192
# Making plot 85 of 192
# Making plot 86 of 192
# Making plot 87 of 192
# Making plot 88 of 192
# Making plot 89 of 192
# Making plot 90 of 192
# Making plot 91 of 192
# Making plot 92 of 192
# Making plot 93 of 192
# Making plot 94 of 192
# Making plot 95 of 192
# Making plot 96 of 192
# Making plot 97 of 192
# Making plot 98 of 192
# Making plot 99 of 192
# Making plot 100 of 192
# Making plot 101 of 192
# Making plot 102 of 192
# Making plot 103 of 192
# Making plot 104 of 192
# Making plot 105 of 192
# Making plot 106 of 192
# Making plot 107 of 192
# Making plot 108 of 192
# Making plot 109 of 192
# Making plot 110 of 192
# Making plot 111 of 192
# Making plot 112 of 192
# Making plot 113 of 192
# Making plot 114 of 192
# Making plot 115 of 192
# Making plot 116 of 192
# Making plot 117 of 192
# Making plot 118 of 192
# Making plot 119 of 192
# Making plot 120 of 192
# Making plot 121 of 192
# Making plot 122 of 192
# Making plot 123 of 192
# Making plot 124 of 192
# Making plot 125 of 192
# Making plot 126 of 192
# Making plot 127 of 192
# Making plot 128 of 192
# Making plot 129 of 192
# Making plot 130 of 192
# Making plot 131 of 192
# Making plot 132 of 192
# Making plot 133 of 192
# Making plot 134 of 192
# Making plot 135 of 192
# Making plot 136 of 192
# Making plot 137 of 192
# Making plot 138 of 192
# Making plot 139 of 192
# Making plot 140 of 192
# Making plot 141 of 192
# Making plot 142 of 192
# Making plot 143 of 192
# Making plot 144 of 192
# Making plot 145 of 192
# Making plot 146 of 192
# Making plot 147 of 192
# Making plot 148 of 192
# Making plot 149 of 192
# Making plot 150 of 192
# Making plot 151 of 192
# Making plot 152 of 192
# Making plot 153 of 192
# Making plot 154 of 192
# Making plot 155 of 192
# Making plot 156 of 192
# Making plot 157 of 192
# Making plot 158 of 192
# Making plot 159 of 192
# Making plot 160 of 192
# Making plot 161 of 192
# Making plot 162 of 192
# Making plot 163 of 192
# Making plot 164 of 192
# Making plot 165 of 192
# Making plot 166 of 192
# Making plot 167 of 192
# Making plot 168 of 192
# Making plot 169 of 192
# Making plot 170 of 192
# Making plot 171 of 192
# Making plot 172 of 192
# Making plot 173 of 192
# Making plot 174 of 192
# Making plot 175 of 192
# Making plot 176 of 192
# Making plot 177 of 192
# Making plot 178 of 192
# Making plot 179 of 192
# Making plot 180 of 192
# Making plot 181 of 192
# Making plot 182 of 192
# Making plot 183 of 192
# Making plot 184 of 192
# Making plot 185 of 192
# Making plot 186 of 192
# Making plot 187 of 192
# Making plot 188 of 192
# Making plot 189 of 192
# Making plot 190 of 192
# Making plot 191 of 192

# %%
rsltmng.make_gif_from_folder(resultsdir+'superplotscanfiles',resultsdir+resultstag+'superplot.gif')
# Making plot 22 of 384
# Making plot 23 of 384
# Making plot 24 of 384
# Making plot 25 of 384
# Making plot 26 of 384
# Making plot 27 of 384
# Making plot 28 of 384
# Making plot 29 of 384
# Making plot 30 of 384
# Making plot 31 of 384
# Making plot 32 of 384
# Making plot 33 of 384
# Making plot 34 of 384
# Making plot 35 of 384
# Making plot 36 of 384
# Making plot 37 of 384
# Making plot 38 of 384
# Making plot 39 of 384
# Making plot 40 of 384
# Making plot 41 of 384
# Making plot 42 of 384
# Making plot 43 of 384
# Making plot 44 of 384
# Making plot 45 of 384
# Making plot 46 of 384
# Making plot 47 of 384
# Making plot 48 of 384
# Making plot 49 of 384
# Making plot 50 of 384
# Making plot 51 of 384
# Making plot 52 of 384
# Making plot 53 of 384
# Making plot 54 of 384
# Making plot 55 of 384
# Making plot 56 of 384
# Making plot 57 of 384
# Making plot 58 of 384
# Making plot 59 of 384
# Making plot 60 of 384
# Making plot 61 of 384
# Making plot 62 of 384
# Making plot 63 of 384
# Making plot 64 of 384
# Making plot 65 of 384
# Making plot 66 of 384
# Making plot 67 of 384
# Making plot 68 of 384
# Making plot 69 of 384
# Making plot 70 of 384
# Making plot 71 of 384
# Making plot 72 of 384
# Making plot 73 of 384
# Making plot 74 of 384
# Making plot 75 of 384
# Making plot 76 of 384
# Making plot 77 of 384
# Making plot 78 of 384
# Making plot 79 of 384
# Making plot 80 of 384
# Making plot 81 of 384
# Making plot 82 of 384
# Making plot 83 of 384
# Making plot 84 of 384
# Making plot 85 of 384
# Making plot 86 of 384
# Making plot 87 of 384
# Making plot 88 of 384
# Making plot 89 of 384
# Making plot 90 of 384
# Making plot 91 of 384
# Making plot 92 of 384
# Making plot 93 of 384
# Making plot 94 of 384
# Making plot 95 of 384
# Making plot 96 of 384
# Making plot 97 of 384
# Making plot 98 of 384
# Making plot 99 of 384
# Making plot 100 of 384
# Making plot 101 of 384
# Making plot 102 of 384
# Making plot 103 of 384
# Making plot 104 of 384
# Making plot 105 of 384
# Making plot 106 of 384
# Making plot 107 of 384
# Making plot 108 of 384
# Making plot 109 of 384
# Making plot 110 of 384
# Making plot 111 of 384
# Making plot 112 of 384
# Making plot 113 of 384
# Making plot 114 of 384
# Making plot 115 of 384
# Making plot 116 of 384
# Making plot 117 of 384
# Making plot 118 of 384
# Making plot 119 of 384
# Making plot 120 of 384
# Making plot 121 of 384
# Making plot 122 of 384
# Making plot 123 of 384
# Making plot 124 of 384
# Making plot 125 of 384
# Making plot 126 of 384
# Making plot 127 of 384
# Making plot 128 of 384
# Making plot 129 of 384
# Making plot 130 of 384
# Making plot 131 of 384
# Making plot 132 of 384
# Making plot 133 of 384
# Making plot 134 of 384
# Making plot 135 of 384
# Making plot 136 of 384
# Making plot 137 of 384
# Making plot 138 of 384
# Making plot 139 of 384
# Making plot 140 of 384
# Making plot 141 of 384
# Making plot 142 of 384
# Making plot 143 of 384
# Making plot 144 of 384
# Making plot 145 of 384
# Making plot 146 of 384
# Making plot 147 of 384
# Making plot 148 of 384
# Making plot 149 of 384
# Making plot 150 of 384
# Making plot 151 of 384
# Making plot 152 of 384
# Making plot 153 of 384
# Making plot 154 of 384
# Making plot 155 of 384
# Making plot 156 of 384
# Making plot 157 of 384
# Making plot 158 of 384
# Making plot 159 of 384
# Making plot 160 of 384
# Making plot 161 of 384
# Making plot 162 of 384
# Making plot 163 of 384
# Making plot 164 of 384
# Making plot 165 of 384
# Making plot 166 of 384
# Making plot 167 of 384
# Making plot 168 of 384
# Making plot 169 of 384
# Making plot 170 of 384
# Making plot 171 of 384
# Making plot 172 of 384
# Making plot 173 of 384
# Making plot 174 of 384
# Making plot 175 of 384
# Making plot 176 of 384
# Making plot 177 of 384
# Making plot 178 of 384
# Making plot 179 of 384
# Making plot 180 of 384
# Making plot 181 of 384
# Making plot 182 of 384
# Making plot 183 of 384
# Making plot 184 of 384
# Making plot 185 of 384
# Making plot 186 of 384
# Making plot 187 of 384
# Making plot 188 of 384
# Making plot 189 of 384
# Making plot 190 of 384
# Making plot 191 of 384
# Making plot 192 of 384
# Making plot 193 of 384
# Making plot 194 of 384
# Making plot 195 of 384
# Making plot 196 of 384
# Making plot 197 of 384
# Making plot 198 of 384
# Making plot 199 of 384
# Making plot 200 of 384
# Making plot 201 of 384
# Making plot 202 of 384
# Making plot 203 of 384
# Making plot 204 of 384
# Making plot 205 of 384
# Making plot 206 of 384
# Making plot 207 of 384
# Making plot 208 of 384
# Making plot 209 of 384
# Making plot 210 of 384
# Making plot 211 of 384
# Making plot 212 of 384
# Making plot 213 of 384
# Making plot 214 of 384
# Making plot 215 of 384
# Making plot 216 of 384
# Making plot 217 of 384
# Making plot 218 of 384
# Making plot 219 of 384
# Making plot 220 of 384
# Making plot 221 of 384
# Making plot 222 of 384
# Making plot 223 of 384
# Making plot 224 of 384
# Making plot 225 of 384
# Making plot 226 of 384
# Making plot 227 of 384
# Making plot 228 of 384
# Making plot 229 of 384
# Making plot 230 of 384
# Making plot 231 of 384
# Making plot 232 of 384
# Making plot 233 of 384
# Making plot 234 of 384
# Making plot 235 of 384
# Making plot 236 of 384
# Making plot 237 of 384
# Making plot 238 of 384
# Making plot 239 of 384
# Making plot 240 of 384
# Making plot 241 of 384
# Making plot 242 of 384
# Making plot 243 of 384
# Making plot 244 of 384
# Making plot 245 of 384
# Making plot 246 of 384
# Making plot 247 of 384
# Making plot 248 of 384
# Making plot 249 of 384
# Making plot 250 of 384
# Making plot 251 of 384
# Making plot 252 of 384
# Making plot 253 of 384
# Making plot 254 of 384
# Making plot 255 of 384
# Making plot 256 of 384
# Making plot 257 of 384
# Making plot 258 of 384
# Making plot 259 of 384
# Making plot 260 of 384
# Making plot 261 of 384
# Making plot 262 of 384
# Making plot 263 of 384
# Making plot 264 of 384
# Making plot 265 of 384
# Making plot 266 of 384
# Making plot 267 of 384
# Making plot 268 of 384
# Making plot 269 of 384
# Making plot 270 of 384
# Making plot 271 of 384
# Making plot 272 of 384
# Making plot 273 of 384
# Making plot 274 of 384
# Making plot 275 of 384
# Making plot 276 of 384
# Making plot 277 of 384
# Making plot 278 of 384
# Making plot 279 of 384
# Making plot 280 of 384
# Making plot 281 of 384
# Making plot 282 of 384
# Making plot 283 of 384
# Making plot 284 of 384
# Making plot 285 of 384
# Making plot 286 of 384
# Making plot 287 of 384
# Making plot 288 of 384
# Making plot 289 of 384
# Making plot 290 of 384
# Making plot 291 of 384
# Making plot 292 of 384
# Making plot 293 of 384
# Making plot 294 of 384
# Making plot 295 of 384
# Making plot 296 of 384
# Making plot 297 of 384
# Making plot 298 of 384
# Making plot 299 of 384
# Making plot 300 of 384
# Making plot 301 of 384
# Making plot 302 of 384
# Making plot 303 of 384
# Making plot 304 of 384
# Making plot 305 of 384
# Making plot 306 of 384
# Making plot 307 of 384
# Making plot 308 of 384
# Making plot 309 of 384
# Making plot 310 of 384
# Making plot 311 of 384
# Making plot 312 of 384
# Making plot 313 of 384
# Making plot 314 of 384
# Making plot 315 of 384
# Making plot 316 of 384
# Making plot 317 of 384
# Making plot 318 of 384
# Making plot 319 of 384
# Making plot 320 of 384
# Making plot 321 of 384
# Making plot 322 of 384
# Making plot 323 of 384
# Making plot 324 of 384
# Making plot 325 of 384
# Making plot 326 of 384
# Making plot 327 of 384
# Making plot 328 of 384
# Making plot 329 of 384
# Making plot 330 of 384
# Making plot 331 of 384
# Making plot 332 of 384
# Making plot 333 of 384
# Making plot 334 of 384
# Making plot 335 of 384
# Making plot 336 of 384
# Making plot 337 of 384
# Making plot 338 of 384
# Making plot 339 of 384
# Making plot 340 of 384
# Making plot 341 of 384
# Making plot 342 of 384
# Making plot 343 of 384
# Making plot 344 of 384
# Making plot 345 of 384
# Making plot 346 of 384
# Making plot 347 of 384
# Making plot 348 of 384
# Making plot 349 of 384
# Making plot 350 of 384
# Making plot 351 of 384
# Making plot 352 of 384
# Making plot 353 of 384
# Making plot 354 of 384
# Making plot 355 of 384
# Making plot 356 of 384
# Making plot 357 of 384
# Making plot 358 of 384
# Making plot 359 of 384
# Making plot 360 of 384
# Making plot 361 of 384
# Making plot 362 of 384
# Making plot 363 of 384
# Making plot 364 of 384
# Making plot 365 of 384
# Making plot 366 of 384
# Making plot 367 of 384
# Making plot 368 of 384
# Making plot 369 of 384
# Making plot 370 of 384
# Making plot 371 of 384
# Making plot 372 of 384
# Making plot 373 of 384
# Making plot 374 of 384
# Making plot 375 of 384
# Making plot 376 of 384
# Making plot 377 of 384
# Making plot 378 of 384
# Making plot 379 of 384
# Making plot 380 of 384
# Making plot 381 of 384
# Making plot 382 of 384
# Making plot 383 of 384

# %%
rsltmng.make_gif_from_folder(resultsdir+'fieldscanfiles',resultsdir+resultstag+'fieldscan.gif')
# Out:
