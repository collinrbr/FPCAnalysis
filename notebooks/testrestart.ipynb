# %% [markdown]
# # test restart
# Here we test the restart loader libraries

# %%
#Need this to add libraries in parent folder
import sys
sys.path.append('..')
sys.path.append('.')
sys.path.append('../lib')

# %%
import lib.analysis as anl 
import lib.array_ops as ao
import lib.data_h5 as dh5
import lib.data_netcdf4 as dnc
import lib.fpc as fpc
import lib.frametransform as ft
import lib.metadata as md

import lib.plot.oned as plt1d
import lib.plot.twod as plt2d
import lib.plot.debug as pltdebug
import lib.plot.fourier as pltfr
import lib.plot.resultsmanager as rsltmng
import lib.plot.velspace as pltvv

import os
import math
import numpy as np
# Out:
# /home/collbrown/dHybridR/analysis/dHybridRAnalysis/notebooks/../lib/data_h5.py:242: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if path[-1] is not '/': path = path + '/'
# /home/collbrown/dHybridR/analysis/dHybridRAnalysis/notebooks/../lib/data_h5.py:336: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if path[-1] is not '/': path = path + '/'
# /home/collbrown/dHybridR/analysis/dHybridRAnalysis/notebooks/../lib/data_h5.py:426: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if path[-1] is not '/': path = path + '/'

# %%
def debug_hist(data):
    import matplotlib.pyplot as plt
    binsplt = np.linspace(min(data),max(data),1000)
    
    plt.figure()
    plt.hist(data, bins = binsplt)
    
    plt.show()

# %%
pathrestart = '/home/collbrown/dHybridR/analysis/dHybridRAnalysis/testdata/secondrun'

# %%
import h5py

# %%
pts = dh5.read_restart(pathrestart)

# %%
pts
# Out:
# array([[ 4.3678535e+01,  1.1337780e+01,  1.0673775e+01, ...,
#         -4.0631757e+00,  7.0612186e-01,  1.0000000e-03],
#        [ 4.2769112e+01,  1.1491739e+01,  9.3985891e+00, ...,
#         -5.8578479e-01,  9.1185963e-01,  1.0000000e-03],
#        [ 4.6889374e+01,  1.0710739e+01,  1.2032443e+01, ...,
#          2.3821871e+00, -4.6685633e-01,  1.0000000e-03],
#        ...,
#        [ 4.2166084e+01,  1.0199719e+01,  1.0331110e+01, ...,
#         -6.4019507e-01, -1.2487675e+00,  1.0000000e-03],
#        [ 4.2258492e+01,  1.0285507e+01,  1.0461638e+01, ...,
#          8.8545692e-01,  1.6323533e+00,  1.0000000e-03],
#        [ 4.2344730e+01,  1.0308973e+01,  1.0340565e+01, ...,
#         -9.5633233e-01, -4.5765954e-01,  1.0000000e-03]], dtype=float32)

# %%
debug_hist([pts[i][0] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][1] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][2] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][3] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][4] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][5] for i in range(0,len(pts))])

# %%
debug_hist([pts[i][6] for i in range(0,len(pts))])
